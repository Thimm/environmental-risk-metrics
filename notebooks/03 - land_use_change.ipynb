# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
from environmental_risk_metrics import EsaLandCover, EsriLandCover, OpenLandMapLandCover
import geopandas as gpd

# Configure logging to display in Jupyter
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s",
    force=True,  # This ensures the configuration is applied even if logging was previously configured
)
logger = logging.getLogger(__name__)



polygon = {
    "type": "Feature",
    "properties": {},
    "geometry": {
        "coordinates": [
            [
                [10.235198982658801, 51.42076009745068],
                [10.236477278753114, 51.41697045550828],
                [10.244461712820623, 51.41823370440062],
                [10.242888425319222, 51.4220355049745],
                [10.235198982658801, 51.42076009745068],
            ]
        ],
        "type": "Polygon",
    },
}
gdf = gpd.GeoDataFrame.from_features([polygon, polygon], crs="EPSG:4326")
start_date = "2000-01-01"
end_date = "2025-12-31"


esa_land_cover = EsaLandCover(gdf=gdf)
openlandmap_land_cover = OpenLandMapLandCover(gdf=gdf)
esri_land_cover = EsriLandCover(gdf=gdf)


esa_land_cover_data = esa_land_cover.get_data(
    start_date=start_date,
    end_date=end_date,
)

openlandmap_land_cover_data = openlandmap_land_cover.get_data(
    start_date=start_date,
    end_date=end_date,
)

esri_land_cover_data = esri_land_cover.get_data(
    start_date=start_date,
    end_date=end_date,
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 46
#      38 esri_land_cover = EsriLandCover(gdf=gdf)
#      41 esa_land_cover_data = esa_land_cover.get_data(
#      42     start_date=start_date,
#      43     end_date=end_date,
#      44 )
# ---> 46 openlandmap_land_cover_data = openlandmap_land_cover.get_data(
#      47     start_date=start_date,
#      48     end_date=end_date,
#      49 )
#      51 esri_land_cover_data = esri_land_cover.get_data(
#      52     start_date=start_date,
#      53     end_date=end_date,
#      54 )
#
# File ~/environmental-risk-metrics/src/environmental_risk_metrics/metrics/land_use_change.py:342, in BaseLandCover.get_data(self, start_date, end_date, all_touched)
#     325 def get_data(
#     326     self,
#     327     start_date: str,
#     328     end_date: str,
#     329     all_touched: bool = True,
#     330 ) -> List[List[Dict[str, Any]]]:
#     331     """Get land use class areas for a given geometry.
#     332
#     333     Args:
#    (...)
#     340         areas in square meters for each polygon and time step.
#     341     """
# --> 342     area_dicts = self.get_land_use_metrics(
#     343         start_date=start_date,
#     344         end_date=end_date,
#     345         all_touched=all_touched,
#     346     )
#     348     # Get ESRI class labels (not the raw numbers)
#     349     esri_labels = list(ESRI_LAND_COVER_LEGEND.values())
#
# File ~/environmental-risk-metrics/src/environmental_risk_metrics/metrics/land_use_change.py:459, in OpenLandMapLandCover.get_land_use_metrics(self, start_date, end_date, all_touched)
#     444 """Calculate land use class areas from GLAD data.
#     445
#     446 This method overrides the base implementation to handle the specifics of
#    (...)
#     456     for each polygon.
#     457 """
#     458 area_list = []
# --> 459 ds_list = self.load_xarray(
#     460     start_date=start_date,
#     461     end_date=end_date,
#     462 )
#     463 for ds, geometry in zip(ds_list, self.gdf["geometry"]):
#     464     # First clip the data in its native CRS (4326)
#     465     clipped_data = ds.rio.clip([geometry], self.gdf.crs, all_touched=all_touched)
#
# AttributeError: 'OpenLandMapLandCover' object has no attribute 'load_xarray'

# %%
data = esri_land_cover.get_items(start_date=start_date, end_date=end_date, polygon=gdf, polygon_crs=gdf.crs)

# %%
esa_land_cover_data
# Out:
# [{2000: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2001: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2002: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2003: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2004: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2005: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2006: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2007: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2008: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2009: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2010: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2011: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2012: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2013: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2014: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2015: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2016: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2017: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2018: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2019: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2020: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0}},
#  {2000: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2001: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2002: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2003: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2004: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2005: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2006: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2007: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2008: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2009: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2010: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2011: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2012: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2013: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2014: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2015: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2016: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2017: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2018: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2019: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   2020: {'Crops': 24.43,
#    'No Data': 0,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0}}]

# %%
esri_land_cover_data
# Out:
# [{'2023': {'Crops': 24.42},
#   '2022': {'Crops': 24.42},
#   '2021': {'Crops': 24.42},
#   '2020': {'Crops': 24.42},
#   '2019': {'Crops': 24.42},
#   '2018': {'Crops': 24.42},
#   '2017': {'Crops': 24.42}},
#  {'2023': {'Crops': 24.42},
#   '2022': {'Crops': 24.42},
#   '2021': {'Crops': 24.42},
#   '2020': {'Crops': 24.42},
#   '2019': {'Crops': 24.42},
#   '2018': {'Crops': 24.42},
#   '2017': {'Crops': 24.42}}]

# %%
esri_land_cover.get_items(start_date=start_date, end_date=end_date, polygon=gdf, polygon_crs=gdf.crs)
# Out:
# <style>
# .pystac-summary {
#     cursor: pointer;
#     display: list-item;
#     list-style: revert;
#     margin-bottom: 0 !important;
#
#     .pystac-l {
#         padding-left: 0.5em;
#         color: rgb(64, 128, 128);
#         font-style: italic;
#     }
# }
# .pystac-row {
#     overflow-wrap: break-word;
#     padding-left: .825em;
#
#     .pystac-k {
#         display: inline-block;
#         margin: 0px 0.5em 0px 0px;
#     }
#     .pystac-v {
#         color: rgb(186, 33, 33);
#     }
# }
# .pystac-k {
#     color: rgb(0, 128, 0);
#     font-weight: 700;
# }
# </style>
# <div class="jp-RenderedJSON jp-mod-trusted jp-OutputArea-output">
#     <div class="container" style="line-height: normal;">
#         <ul style="padding: 0px; margin: 0px; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">type</span>
#             <span class="pystac-v">"FeatureCollection"</span>
#         </li>
#
#
#
#
#                     <li><details>
#         <summary class="pystac-summary"><span class="pystac-k">features</span><span class="pystac-l">[] 7 items</span></summary>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li><details>
#             <summary class="pystac-summary"><span class="pystac-k">0</span></summary>
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">type</span>
#             <span class="pystac-v">"Feature"</span>
#         </li>
#
#
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">stac_version</span>
#             <span class="pystac-v">"1.0.0"</span>
#         </li>
#
#
#
#
#                 <li><details>
#         <summary class="pystac-summary"><span class="pystac-k">stac_extensions</span><span class="pystac-l">[] 3 items</span></summary>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">0</span>
#             <span class="pystac-v">"https://stac-extensions.github.io/projection/v1.1.0/schema.json"</span>
#         </li>
#
#
#
#     </ul>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">1</span>
#             <span class="pystac-v">"https://stac-extensions.github.io/file/v2.0.0/schema.json"</span>
#         </li>
#
#
#
#     </ul>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">2</span>
#             <span class="pystac-v">"https://stac-extensions.github.io/raster/v1.1.0/schema.json"</span>
#         </li>
#
#
#
#     </ul>
#
#     </details></li>
#
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">id</span>
#             <span class="pystac-v">"32U-2023"</span>
#         </li>
#
#
#
#
#
#         <li><details>
#             <summary class="pystac-summary"><span class="pystac-k">geometry</span></summary>
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">type</span>
#             <span class="pystac-v">"Polygon"</span>
#         </li>
#
#
#
#
#                 <li><details>
#         <summary class="pystac-summary"><span class="pystac-k">coordinates</span><span class="pystac-l">[] 1 items</span></summary>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#                 <li><details>
#         <summary class="pystac-summary"><span class="pystac-k">0</span><span class="pystac-l">[] 85 items</span></summary>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#                 <li><details>
#         <summary class="pystac-summary"><span class="pystac-k">0</span><span class="pystac-l">[] 2 items</span></summary>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">0</span>
#             <span class="pystac-v">6.002342574737061</span>
#         </li>
#
#
#
#     </ul>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">1</span>
#             <span class="pystac-v">47.96095567136579</span>
#         </li>
#
#
#
#     </ul>
#
#     </details></li>
#
#
#     </ul>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#                 <li><details>
#         <summary class="pystac-summary"><span class="pystac-k">1</span><span class="pystac-l">[] 2 items</span></summary>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">0</span>
#             <span class="pystac-v">6.287485147094801</span>
#         </li>
#
#
#
#     </ul>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">1</span>
#             <span class="pystac-v">47.96804935107791</span>
#         </li>
#
#
#
#     </ul>
#
#     </details></li>
#
#
#     </ul>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#                 <li><details>
#         <summary class="pystac-summary"><span class="pystac-k">2</span><span class="pystac-l">[] 2 items</span></summary>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">0</span>
#             <span class="pystac-v">6.572732172741235</span>
#         </li>
#
#
#
#     </ul>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">1</span>
#             <span class="pystac-v">47.97443561173897</span>
#         </li>
#
#
#
#     </ul>
#
#     </details></li>
#
#
#     </ul>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#                 <li><details>
#         <summary class="pystac-summary"><span class="pystac-k">3</span><span class="pystac-l">[] 2 items</span></summary>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">0</span>

# %%
esa_data = esa_land_cover.load_xarray(start_date=start_date, end_date=end_date)
# Out:
# 100%|██████████| 21/21 [00:00<00:00, 396.80it/s]
# 100%|██████████| 21/21 [00:00<00:00, 477.13it/s]

# %%
data = esa_land_cover.get_items(start_date=start_date, end_date=end_date, polygon=polygon, polygon_crs="EPSG:4326")

# %%
raster_path = data[0].assets["lccs_class"].href

with rasterio.open(raster_path) as src:
    resolution = src.res
    crs = src.crs
    # Calculate pixel area in hectares directly
    pixel_area_ha = abs(resolution[0] * resolution[1]) / 10000

# %%
from rasterstats import zonal_stats
import rasterio

# Get the raster file path
raster_path = data[0].assets["lccs_class"].href

# Open raster and get basic info
with rasterio.open(raster_path) as src:
    resolution = src.res
    crs = src.crs
    # Calculate pixel area in hectares directly
    pixel_area_ha = abs(resolution[0] * resolution[1]) / 10000

# Count pixels per land cover class within each polygon
stats_dict = zonal_stats(
    gdf,
    raster_path, 
    categorical=True,
    all_touched=False  # Only count pixels with centers inside polygon
)

# Convert pixel counts to hectares and scale to match expected area
expected_total_ha = 24.4226
areas_dict = []

for polygon_stats in stats_dict:
    total_pixels = sum(polygon_stats.values())
    scaling_factor = expected_total_ha / (total_pixels * pixel_area_ha)
    
    # Calculate area in hectares for each class
    area_stats = {
        class_id: count * pixel_area_ha * scaling_factor 
        for class_id, count in polygon_stats.items()
    }
    areas_dict.append(area_stats)

# %%
# Out:
# (0.002777777777777778, 0.0027777777777777783)
# EPSG:4326

# %%
crs
# Out:
# CRS.from_wkt('GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]')

# %%
from rasterstats import zonal_stats
import rasterio

# Get the raster file path
raster_path = data[0].assets["lccs_class"].href

# Open raster and get basic info
with rasterio.open(raster_path) as src:
    resolution = src.res
    crs = src.crs
    # Calculate pixel area in hectares directly
    pixel_area_ha = abs(resolution[0] * resolution[1]) / 10000

# Count pixels per land cover class within each polygon
stats_dict = zonal_stats(
    gdf,
    raster_path, 
    categorical=True,
    all_touched=False  # Only count pixels with centers inside polygon
)

# Convert pixel counts to hectares and scale to match expected area
expected_total_ha = 24.4226
areas_dict = []

for polygon_stats in stats_dict:
    total_pixels = sum(polygon_stats.values())
    scaling_factor = expected_total_ha / (total_pixels * pixel_area_ha)
    
    # Calculate area in hectares for each class
    area_stats = {
        class_id: count * pixel_area_ha * scaling_factor 
        for class_id, count in polygon_stats.items()
    }
    areas_dict.append(area_stats)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       2 import rasterio
#       4 # Get the raster file path
# ----> 5 raster_path = data[0].assets["lccs_class"].href
#       7 # Open raster and get basic info
#       8 with rasterio.open(raster_path) as src:
#
# NameError: name 'data' is not defined

# %%
244226 / 10000
# Out:
# 24.4226

# %%
areas_dict
# Out:
# [{11: 20.352166666666665, 30: 4.070433333333333},
#  {11: 20.352166666666665, 30: 4.070433333333333}]

# %%
stats_dict
# Out:
# [{11: 5, 30: 1}, {11: 5, 30: 1}]

# %%
# Get the data
ds_list = esa_land_cover.load_xarray(
    start_date=start_date,
    end_date=end_date,
)

area_list = []
for ds, polygon in zip(ds_list, gdf["geometry"]):
    # First clip the data in its native CRS (4326)
    clipped_data = ds.rio.clip(
        [polygon], crs=gdf.crs, all_touched=True
    )
    clipped_data = clipped_data.where(clipped_data[esa_land_cover.band_name] != 0)
    
    # Now reproject to equal-area projection for accurate area calculation
    # Mask again with the polygon in 6933
    polygon_proj = gpd.GeoSeries([polygon], crs=gdf.crs).to_crs(clipped_data.rio.crs).iloc[0]
    clipped_data_projected = clipped_data.rio.clip([polygon_proj], crs="EPSG:6933", all_touched=True)
    
    # Get pixel area from the projected data
    res = clipped_data_projected.rio.resolution()[0]
    pixel_area_sqm = res

    clipped_data_df = clipped_data_projected.to_dataframe()
    clipped_data_df[esa_land_cover.band_name] = clipped_data_df[esa_land_cover.band_name].map(
        esa_land_cover.get_legend_labels_dict()
    )
    grouped = clipped_data_df.groupby("time")
    value_counts = grouped[esa_land_cover.band_name].value_counts()

    area = value_counts * pixel_area_sqm
    area_list.append(round(area.unstack(level=1), 2))

data = area_list
# Out:
# 100%|██████████| 21/21 [00:00<00:00, 452.73it/s]
# 100%|██████████| 21/21 [00:00<00:00, 474.90it/s]
# ---------------------------------------------------------------------------
# NoDataInBounds                            Traceback (most recent call last)
# Cell In[9], line 18
#      15 # Now reproject to equal-area projection for accurate area calculation
#      16 # Mask again with the polygon in 6933
#      17 polygon_proj = gpd.GeoSeries([polygon], crs=gdf.crs).to_crs(clipped_data.rio.crs).iloc[0]
# ---> 18 clipped_data_projected = clipped_data.rio.clip([polygon_proj], crs="EPSG:6933", all_touched=True)
#      20 # Get pixel area from the projected data
#      21 res = clipped_data_projected.rio.resolution()[0]
#
# File ~/environmental-risk-metrics/.venv/lib/python3.10/site-packages/rioxarray/raster_dataset.py:393, in RasterDataset.clip(self, geometries, crs, all_touched, drop, invert, from_disk)
#     390 try:
#     391     x_dim, y_dim = _get_spatial_dims(self._obj, var=var)
#     392     clipped_dataset[var] = (
# --> 393         self._obj[var]
#     394         .rio.set_spatial_dims(x_dim=x_dim, y_dim=y_dim, inplace=True)
#     395         .rio.clip(
#     396             geometries,
#     397             crs=crs,
#     398             all_touched=all_touched,
#     399             drop=drop,
#     400             invert=invert,
#     401             from_disk=from_disk,
#     402         )
#     403     )
#     404 except MissingSpatialDimensionError:
#     405     if len(self._obj[var].dims) >= 2 and not get_option(
#     406         SKIP_MISSING_SPATIAL_DIMS
#     407     ):
#
# File ~/environmental-risk-metrics/.venv/lib/python3.10/site-packages/rioxarray/raster_array.py:974, in RasterArray.clip(self, geometries, crs, all_touched, drop, invert, from_disk)
#     962     cropped_ds = _clip_xarray(
#     963         self._obj,
#     964         geometries=geometries,
#    (...)
#     967         invert=invert,
#     968     )
#     970 if (
#     971     cropped_ds.coords[self.x_dim].size < 1
#     972     or cropped_ds.coords[self.y_dim].size < 1
#     973 ):
# --> 974     raise NoDataInBounds(
#     975         f"No data found in bounds.{_get_data_var_message(self._obj)}"
#     976     )
#     978 # make sure correct attributes preserved & projection added
#     979 _add_attrs_proj(new_data_array=cropped_ds, src_data_array=self._obj)
#
# NoDataInBounds: No data found in bounds. Data variable: lccs_class

# %%
data[0]
# Out:
# lccs_class   Crops
# time
# 2000-01-01  2127.0
# 2001-01-01  2127.0
# 2002-01-01  2127.0
# 2003-01-01  2127.0
# 2004-01-01  2127.0
# 2005-01-01  2127.0
# 2006-01-01  2127.0
# 2007-01-01  2127.0
# 2008-01-01  2127.0
# 2009-01-01  2127.0
# 2010-01-01  2127.0
# 2011-01-01  2127.0
# 2012-01-01  2127.0
# 2013-01-01  2127.0
# 2014-01-01  2127.0
# 2015-01-01  2127.0
# 2016-01-01  2127.0
# 2017-01-01  2127.0
# 2018-01-01  2127.0
# 2019-01-01  2127.0
# 2020-01-01  2127.0

# %%
data = esa_land_cover.load_xarray(start_date=start_date, end_date=end_date)
# Out:
# 100%|██████████| 21/21 [00:00<00:00, 390.43it/s]
# 100%|██████████| 21/21 [00:00<00:00, 424.20it/s]

# %%
data[0].rio.crs
# Out:
# CRS.from_wkt('PROJCS["WGS 84 / UTM zone 32N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",9],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32632"]]')

# %%
754021.18/30
# Out:
# 25134.039333333334

# %%
esri_land_cover_data
# Out:
# [[{'date': Timestamp('2017-01-01 00:00:00'),
#    'Crops': 720000.0,
#    'No Data': 270000.0,
#    'Trees': 90000.0,
#    'Water': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   {'date': Timestamp('2018-01-01 00:00:00'),
#    'Crops': 810000.0,
#    'No Data': 270000.0,
#    'Trees': 0.0,
#    'Water': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   {'date': Timestamp('2019-01-01 00:00:00'),
#    'Crops': 810000.0,
#    'No Data': 270000.0,
#    'Trees': 0.0,
#    'Water': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   {'date': Timestamp('2020-01-01 00:00:00'),
#    'Crops': 810000.0,
#    'No Data': 270000.0,
#    'Trees': 0.0,
#    'Water': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   {'date': Timestamp('2021-01-01 00:00:00'),
#    'Crops': 810000.0,
#    'No Data': 270000.0,
#    'Trees': 0.0,
#    'Water': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   {'date': Timestamp('2022-01-01 00:00:00'),
#    'Crops': 810000.0,
#    'No Data': 270000.0,
#    'Trees': 0.0,
#    'Water': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   {'date': Timestamp('2023-01-01 00:00:00'),
#    'Crops': 810000.0,
#    'No Data': 270000.0,
#    'Trees': 0.0,
#    'Water': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0}],
#  [{'date': Timestamp('2017-01-01 00:00:00'),
#    'Crops': 720000.0,
#    'No Data': 270000.0,
#    'Trees': 90000.0,
#    'Water': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   {'date': Timestamp('2018-01-01 00:00:00'),
#    'Crops': 810000.0,
#    'No Data': 270000.0,
#    'Trees': 0.0,
#    'Water': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   {'date': Timestamp('2019-01-01 00:00:00'),
#    'Crops': 810000.0,
#    'No Data': 270000.0,
#    'Trees': 0.0,
#    'Water': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   {'date': Timestamp('2020-01-01 00:00:00'),
#    'Crops': 810000.0,
#    'No Data': 270000.0,
#    'Trees': 0.0,
#    'Water': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   {'date': Timestamp('2021-01-01 00:00:00'),
#    'Crops': 810000.0,
#    'No Data': 270000.0,
#    'Trees': 0.0,
#    'Water': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   {'date': Timestamp('2022-01-01 00:00:00'),
#    'Crops': 810000.0,
#    'No Data': 270000.0,
#    'Trees': 0.0,
#    'Water': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   {'date': Timestamp('2023-01-01 00:00:00'),
#    'Crops': 810000.0,
#    'No Data': 270000.0,
#    'Trees': 0.0,
#    'Water': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0}]]

# %%
esri_land_cover_data
# Out:
# [[{'date': Timestamp('2017-01-01 00:00:00'),
#    'Crops': 256042.16,
#    'No Data': 19080.68,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   {'date': Timestamp('2018-01-01 00:00:00'),
#    'Crops': 256042.16,
#    'No Data': 19080.68,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   {'date': Timestamp('2019-01-01 00:00:00'),
#    'Crops': 256042.16,
#    'No Data': 19080.68,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   {'date': Timestamp('2020-01-01 00:00:00'),
#    'Crops': 256042.16,
#    'No Data': 19080.68,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   {'date': Timestamp('2021-01-01 00:00:00'),
#    'Crops': 256042.16,
#    'No Data': 19080.68,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   {'date': Timestamp('2022-01-01 00:00:00'),
#    'Crops': 256042.16,
#    'No Data': 19080.68,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   {'date': Timestamp('2023-01-01 00:00:00'),
#    'Crops': 256042.16,
#    'No Data': 19080.68,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0}],
#  [{'date': Timestamp('2017-01-01 00:00:00'),
#    'Crops': 256042.16,
#    'No Data': 19080.68,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   {'date': Timestamp('2018-01-01 00:00:00'),
#    'Crops': 256042.16,
#    'No Data': 19080.68,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   {'date': Timestamp('2019-01-01 00:00:00'),
#    'Crops': 256042.16,
#    'No Data': 19080.68,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   {'date': Timestamp('2020-01-01 00:00:00'),
#    'Crops': 256042.16,
#    'No Data': 19080.68,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   {'date': Timestamp('2021-01-01 00:00:00'),
#    'Crops': 256042.16,
#    'No Data': 19080.68,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   {'date': Timestamp('2022-01-01 00:00:00'),
#    'Crops': 256042.16,
#    'No Data': 19080.68,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0},
#   {'date': Timestamp('2023-01-01 00:00:00'),
#    'Crops': 256042.16,
#    'No Data': 19080.68,
#    'Water': 0,
#    'Trees': 0,
#    'Flooded vegetation': 0,
#    'Built area': 0,
#    'Bare ground': 0,
#    'Snow/ice': 0,
#    'Clouds': 0,
#    'Rangeland': 0}]]

# %%
data
# Out:
# [[{'date': Timestamp('2000-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2001-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2002-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2003-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2004-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2005-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2006-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2007-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2008-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2009-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2010-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2011-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2012-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2013-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2014-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2015-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2016-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2017-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2018-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2019-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2020-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0}],
#  [{'date': Timestamp('2000-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2001-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2002-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2003-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2004-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2005-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2006-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2007-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2008-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2009-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2010-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2011-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2012-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2013-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2014-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2015-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2016-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2017-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2018-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2019-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0},
#   {'date': Timestamp('2020-01-01 00:00:00'),
#    'Crops': 100.0,
#    'Crops_sqm': 720000.0,
#    'No Data': 0,
#    'No Data_sqm': 0,
#    'Rangeland': 0,
#    'Rangeland_sqm': 0,
#    'Trees': 0,
#    'Trees_sqm': 0,
#    'Flooded vegetation': 0,
#    'Flooded vegetation_sqm': 0,
#    'Built area': 0,
#    'Built area_sqm': 0,
#    'Bare ground': 0,
#    'Bare ground_sqm': 0,
#    'Water': 0,
#    'Water_sqm': 0,
#    'Snow/ice': 0,
#    'Snow/ice_sqm': 0}]]

# %%
esri_land_cover = EsriLandCover(gdf=gdf, use_esri_classes=True)

esri = esri_land_cover.load_xarray(
    start_date=start_date,
    end_date=end_date,
)

esri_percentages = esri_land_cover.get_land_use_class_percentages(
    start_date=start_date,
    end_date=end_date,
)

esri_percentages
# Out:
# 100%|██████████| 7/7 [00:00<00:00, 14.58it/s]
# 100%|██████████| 7/7 [00:00<00:00, 95.34it/s]
# 100%|██████████| 7/7 [00:00<00:00, 90.05it/s]
# 100%|██████████| 7/7 [00:00<00:00, 90.96it/s]
# [data        Crops
#  time
#  2017-01-01  100.0
#  2018-01-01  100.0
#  2019-01-01  100.0
#  2020-01-01  100.0
#  2021-01-01  100.0
#  2022-01-01  100.0
#  2023-01-01  100.0,
#  data        Crops
#  time
#  2017-01-01  100.0
#  2018-01-01  100.0
#  2019-01-01  100.0
#  2020-01-01  100.0
#  2021-01-01  100.0
#  2022-01-01  100.0
#  2023-01-01  100.0]

# %%
olanm_land_cover = OpenLandMapLandCover(gdf=gdf, use_esri_classes=True)

olanm = olanm_land_cover.load_xarray(
    start_date=start_date,
    end_date=end_date,
)
olanm
# Out:
# 2025-01-21 17:13:20,914 - rasterio._env - INFO - GDAL signalled an error: err_no=4, msg="`/vsicurl/https://s3.openlandmap.org/arco/lc_glad.glcluc_c_30m_s_20000101_20001231_go_epsg.4326_v20230901.tif' does not exist in the file system, and is not recognized as a supported dataset name."
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/envs/farmon/lib/python3.10/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File ~/miniforge3/envs/farmon/lib/python3.10/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<function open at 0x324fcadd0>, ('https://s3.openlandmap.org/arco/lc_glad.glcluc_c_30m_s_20000101_20001231_go_epsg.4326_v20230901.tif',), 'r', (('sharing', False),), 'fafc16fd-b680-4ebc-874e-d080afff5638']
#
# During handling of the above exception, another exception occurred:
#
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File rasterio/_base.pyx:310, in rasterio._base.DatasetBase.__init__()
#
# File rasterio/_base.pyx:221, in rasterio._base.open_dataset()
#
# File rasterio/_err.pyx:359, in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: '/vsicurl/https://s3.openlandmap.org/arco/lc_glad.glcluc_c_30m_s_20000101_20001231_go_epsg.4326_v20230901.tif' does not exist in the file system, and is not recognized as a supported dataset name.
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# Cell In[12], line 3
#       1 olanm_land_cover = OpenLandMapLandCover(gdf=gdf, use_esri_classes=True)
# ----> 3 olanm = olanm_land_cover.load_xarray(
#       4     start_date=start_date,
#       5     end_date=end_date,
#       6 )
#       7 olanm
#
# File ~/environmental-risk-metrics/src/environmental_risk_metrics/metrics/land_use_change.py:408, in OpenLandMapLandCover.load_xarray(self, start_date, end_date)
#     406 for year in available_years:
#     407     url = OPENLANDMAP_LC[year]
# --> 408     da = rioxarray.open_rasterio(url)
#     409     da = da.assign_coords(time=pd.Timestamp(f"{year}-01-01"))
#     410     da = da.rio.clip_box(
#     411         minx=minx, miny=miny, maxx=maxx, maxy=maxy, crs=self.gdf.crs
#     412     )
#
# File ~/miniforge3/envs/farmon/lib/python3.10/site-packages/rioxarray/_io.py:1135, in open_rasterio(filename, parse_coordinates, chunks, cache, lock, masked, mask_and_scale, variable, group, default_name, decode_times, decode_timedelta, band_as_variable, **open_kwargs)
#    1133     else:
#    1134         manager = URIManager(file_opener, filename, mode="r", kwargs=open_kwargs)
# -> 1135     riods = manager.acquire()
#    1136     captured_warnings = rio_warnings.copy()
#    1138 # raise the NotGeoreferencedWarning if applicable
#
# File ~/miniforge3/envs/farmon/lib/python3.10/site-packages/xarray/backends/file_manager.py:193, in CachingFileManager.acquire(self, needs_lock)
#     178 def acquire(self, needs_lock=True):
#     179     """Acquire a file object from the manager.
#     180
#     181     A new file is only opened if it has expired from the
#    (...)
#     191         An open file object, as returned by ``opener(*args, **kwargs)``.
#     192     """
# --> 193     file, _ = self._acquire_with_cache_info(needs_lock)
#     194     return file
#
# File ~/miniforge3/envs/farmon/lib/python3.10/site-packages/xarray/backends/file_manager.py:217, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     215     kwargs = kwargs.copy()
#     216     kwargs["mode"] = self._mode
# --> 217 file = self._opener(*self._args, **kwargs)
#     218 if self._mode == "w":
#     219     # ensure file doesn't get overridden when opened again
#     220     self._mode = "a"
#
# File ~/miniforge3/envs/farmon/lib/python3.10/site-packages/rasterio/env.py:463, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     460     session = DummySession()
#     462 with env_ctor(session=session):
# --> 463     return f(*args, **kwds)
#
# File ~/miniforge3/envs/farmon/lib/python3.10/site-packages/rasterio/__init__.py:355, in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, opener, **kwargs)
#     352     path = _parse_path(raw_dataset_path)
#     354 if mode == "r":
# --> 355     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     356 elif mode == "r+":
#     357     dataset = get_writer_for_path(path, driver=driver)(
#     358         path, mode, driver=driver, sharing=sharing, **kwargs
#     359     )
#
# File rasterio/_base.pyx:312, in rasterio._base.DatasetBase.__init__()
#
# RasterioIOError: '/vsicurl/https://s3.openlandmap.org/arco/lc_glad.glcluc_c_30m_s_20000101_20001231_go_epsg.4326_v20230901.tif' does not exist in the file system, and is not recognized as a supported dataset name.

# %%
olanm_land_cover.get_land_use_class_percentages(
    start_date=start_date,
    end_date=end_date,
)
# Out:
# 2025-01-21 17:13:27,866 - rasterio._env - INFO - GDAL signalled an error: err_no=4, msg="`/vsicurl/https://s3.openlandmap.org/arco/lc_glad.glcluc_c_30m_s_20000101_20001231_go_epsg.4326_v20230901.tif' does not exist in the file system, and is not recognized as a supported dataset name."
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/envs/farmon/lib/python3.10/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File ~/miniforge3/envs/farmon/lib/python3.10/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<function open at 0x324fcadd0>, ('https://s3.openlandmap.org/arco/lc_glad.glcluc_c_30m_s_20000101_20001231_go_epsg.4326_v20230901.tif',), 'r', (('sharing', False),), '8ea5c72d-a161-4330-83fd-948c6c5ec810']
#
# During handling of the above exception, another exception occurred:
#
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File rasterio/_base.pyx:310, in rasterio._base.DatasetBase.__init__()
#
# File rasterio/_base.pyx:221, in rasterio._base.open_dataset()
#
# File rasterio/_err.pyx:359, in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: '/vsicurl/https://s3.openlandmap.org/arco/lc_glad.glcluc_c_30m_s_20000101_20001231_go_epsg.4326_v20230901.tif' does not exist in the file system, and is not recognized as a supported dataset name.
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 olanm_land_cover.get_land_use_class_percentages(
#       2     start_date=start_date,
#       3     end_date=end_date,
#       4 )
#
# File ~/environmental-risk-metrics/src/environmental_risk_metrics/metrics/land_use_change.py:426, in OpenLandMapLandCover.get_land_use_class_percentages(self, start_date, end_date, all_touched)
#     419 def get_land_use_class_percentages(
#     420     self,
#     421     start_date: str,
#     422     end_date: str,
#     423     all_touched: bool = True,
#     424 ) -> pd.DataFrame:
#     425     percentage_list = []
# --> 426     ds_list = self.load_xarray(
#     427         start_date=start_date,
#     428         end_date=end_date,
#     429     )
#     430     for ds, geometry in zip(ds_list, self.gdf["geometry"]):
#     431         clipped_data = ds.rio.clip(geometry, self.gdf.crs, all_touched=all_touched)
#
# File ~/environmental-risk-metrics/src/environmental_risk_metrics/metrics/land_use_change.py:408, in OpenLandMapLandCover.load_xarray(self, start_date, end_date)
#     406 for year in available_years:
#     407     url = OPENLANDMAP_LC[year]
# --> 408     da = rioxarray.open_rasterio(url)
#     409     da = da.assign_coords(time=pd.Timestamp(f"{year}-01-01"))
#     410     da = da.rio.clip_box(
#     411         minx=minx, miny=miny, maxx=maxx, maxy=maxy, crs=self.gdf.crs
#     412     )
#
# File ~/miniforge3/envs/farmon/lib/python3.10/site-packages/rioxarray/_io.py:1135, in open_rasterio(filename, parse_coordinates, chunks, cache, lock, masked, mask_and_scale, variable, group, default_name, decode_times, decode_timedelta, band_as_variable, **open_kwargs)
#    1133     else:
#    1134         manager = URIManager(file_opener, filename, mode="r", kwargs=open_kwargs)
# -> 1135     riods = manager.acquire()
#    1136     captured_warnings = rio_warnings.copy()
#    1138 # raise the NotGeoreferencedWarning if applicable
#
# File ~/miniforge3/envs/farmon/lib/python3.10/site-packages/xarray/backends/file_manager.py:193, in CachingFileManager.acquire(self, needs_lock)
#     178 def acquire(self, needs_lock=True):
#     179     """Acquire a file object from the manager.
#     180
#     181     A new file is only opened if it has expired from the
#    (...)
#     191         An open file object, as returned by ``opener(*args, **kwargs)``.
#     192     """
# --> 193     file, _ = self._acquire_with_cache_info(needs_lock)
#     194     return file
#
# File ~/miniforge3/envs/farmon/lib/python3.10/site-packages/xarray/backends/file_manager.py:217, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     215     kwargs = kwargs.copy()
#     216     kwargs["mode"] = self._mode
# --> 217 file = self._opener(*self._args, **kwargs)
#     218 if self._mode == "w":
#     219     # ensure file doesn't get overridden when opened again
#     220     self._mode = "a"
#
# File ~/miniforge3/envs/farmon/lib/python3.10/site-packages/rasterio/env.py:463, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     460     session = DummySession()
#     462 with env_ctor(session=session):
# --> 463     return f(*args, **kwds)
#
# File ~/miniforge3/envs/farmon/lib/python3.10/site-packages/rasterio/__init__.py:355, in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, opener, **kwargs)
#     352     path = _parse_path(raw_dataset_path)
#     354 if mode == "r":
# --> 355     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     356 elif mode == "r+":
#     357     dataset = get_writer_for_path(path, driver=driver)(
#     358         path, mode, driver=driver, sharing=sharing, **kwargs
#     359     )
#
# File rasterio/_base.pyx:312, in rasterio._base.DatasetBase.__init__()
#
# RasterioIOError: '/vsicurl/https://s3.openlandmap.org/arco/lc_glad.glcluc_c_30m_s_20000101_20001231_go_epsg.4326_v20230901.tif' does not exist in the file system, and is not recognized as a supported dataset name.

# %%
luc = esa_land_cover.load_xarray(
    start_date=start_date,
    end_date=end_date,
)

class_percentages = esa_land_cover.get_land_use_class_percentages(
    start_date=start_date,
    end_date=end_date,
)
class_percentages
# Out:
# 100%|██████████| 21/21 [00:00<00:00, 130.39it/s]
# 100%|██████████| 21/21 [00:00<00:00, 126.87it/s]
# 100%|██████████| 21/21 [00:00<00:00, 126.11it/s]
# 100%|██████████| 21/21 [00:00<00:00, 126.69it/s]
# [lccs_class  Crops
#  time
#  2000-01-01  100.0
#  2001-01-01  100.0
#  2002-01-01  100.0
#  2003-01-01  100.0
#  2004-01-01  100.0
#  2005-01-01  100.0
#  2006-01-01  100.0
#  2007-01-01  100.0
#  2008-01-01  100.0
#  2009-01-01  100.0
#  2010-01-01  100.0
#  2011-01-01  100.0
#  2012-01-01  100.0
#  2013-01-01  100.0
#  2014-01-01  100.0
#  2015-01-01  100.0
#  2016-01-01  100.0
#  2017-01-01  100.0
#  2018-01-01  100.0
#  2019-01-01  100.0
#  2020-01-01  100.0,
#  lccs_class  Crops
#  time
#  2000-01-01  100.0
#  2001-01-01  100.0
#  2002-01-01  100.0
#  2003-01-01  100.0
#  2004-01-01  100.0
#  2005-01-01  100.0
#  2006-01-01  100.0
#  2007-01-01  100.0
#  2008-01-01  100.0
#  2009-01-01  100.0
#  2010-01-01  100.0
#  2011-01-01  100.0
#  2012-01-01  100.0
#  2013-01-01  100.0
#  2014-01-01  100.0
#  2015-01-01  100.0
#  2016-01-01  100.0
#  2017-01-01  100.0
#  2018-01-01  100.0
#  2019-01-01  100.0
#  2020-01-01  100.0]

# %%
olanm_land_cover = OpenLandMapLandCover(use_esri_classes=True)

olanm_percentages = olanm_land_cover.get_land_use_class_percentages(
    start_date=start_date,
    end_date=end_date,
    polygon=polygon,
    polygon_crs="EPSG:4326",
)
olanm_percentages
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 olanm_land_cover = OpenLandMapLandCover(use_esri_classes=True)
#       3 olanm_percentages = olanm_land_cover.get_land_use_class_percentages(
#       4     start_date=start_date,
#       5     end_date=end_date,
#       6     polygon=polygon,
#       7     polygon_crs="EPSG:4326",
#       8 )
#       9 olanm_percentages
#
# TypeError: OpenLandMapLandCover.__init__() missing 1 required positional argument: 'gdf'

# %%
olanm_land_cover = OpenLandMapLandCover(use_esri_classes=True)
olanm_land_cover.create_map(
    polygons=polygon,
    polygon_crs="EPSG:4326",
)
# Out:
# Map(center=[np.float64(10.239830347739712), np.float64(51.41950298024139)], controls=(ZoomControl(options=['po…
