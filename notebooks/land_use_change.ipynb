# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
from environmental_risk_metrics import EsaLandCover, EsriLandCover, OpenLandMapLandCover
from IPython.display import Image

# Configure logging to display in Jupyter
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s",
    force=True,  # This ensures the configuration is applied even if logging was previously configured
)
logger = logging.getLogger(__name__)


esa_land_cover = EsaLandCover(use_esri_classes=True)

polygon = {
    "type": "Feature",
    "properties": {},
    "geometry": {
        "coordinates": [
            [
                [10.235198982658801, 51.42076009745068],
                [10.236477278753114, 51.41697045550828],
                [10.244461712820623, 51.41823370440062],
                [10.242888425319222, 51.4220355049745],
                [10.235198982658801, 51.42076009745068],
            ]
        ],
        "type": "Polygon",
    },
}

start_date = "2000-01-01"
end_date = "2024-12-31"

# %%
luc = esa_land_cover.load_xarray(
    start_date=start_date,
    end_date=end_date,
    polygon=polygon,
    resolution=0.00009
)

class_percentages = esa_land_cover.get_land_use_class_percentages(
    start_date=start_date,
    end_date=end_date,
    polygon=polygon,
    polygon_crs="EPSG:4326",
    resolution=0.00009
)

class_percentages
# Out:
# 2024-12-19 13:04:53,907 - environmental_risk_metrics.land_use_change - INFO - Loading ['esa-cci-lc'] data at 9e-05m resolution
# 2024-12-19 13:04:54,011 - environmental_risk_metrics.utils.planetary_computer - INFO - Searching for Sentinel-2 items between 2000-01-01 and 2024-12-31
# 2024-12-19 13:04:54,502 - environmental_risk_metrics.utils.planetary_computer - INFO - Found 21 items
#   0%|          | 0/21 [00:00<?, ?it/s]/Users/thimmzwiener/risk-reports/.venv/lib/python3.12/site-packages/rasterio/warp.py:387: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dest = _reproject(
# 100%|██████████| 21/21 [00:00<00:00, 36.02it/s]
# 2024-12-19 13:04:55,113 - environmental_risk_metrics.land_use_change - INFO - Loading ['esa-cci-lc'] data at 9e-05m resolution
# 2024-12-19 13:04:55,223 - environmental_risk_metrics.utils.planetary_computer - INFO - Searching for Sentinel-2 items between 2000-01-01 and 2024-12-31
# 2024-12-19 13:04:55,587 - environmental_risk_metrics.utils.planetary_computer - INFO - Found 21 items
# 100%|██████████| 21/21 [00:00<00:00, 526.57it/s]
# lccs_class  Crops
# time
# 2000-01-01  100.0
# 2001-01-01  100.0
# 2002-01-01  100.0
# 2003-01-01  100.0
# 2004-01-01  100.0
# 2005-01-01  100.0
# 2006-01-01  100.0
# 2007-01-01  100.0
# 2008-01-01  100.0
# 2009-01-01  100.0
# 2010-01-01  100.0
# 2011-01-01  100.0
# 2012-01-01  100.0
# 2013-01-01  100.0
# 2014-01-01  100.0
# 2015-01-01  100.0
# 2016-01-01  100.0
# 2017-01-01  100.0
# 2018-01-01  100.0
# 2019-01-01  100.0
# 2020-01-01  100.0

# %%
esri_land_cover = EsriLandCover()

esri = esri_land_cover.load_xarray(
    start_date=start_date,
    end_date=end_date,
    polygon=polygon,
    resolution=10
)

esri_percentages = esri_land_cover.get_land_use_class_percentages(
    start_date=start_date,
    end_date=end_date,
    polygon=polygon,
    polygon_crs="EPSG:4326",
    resolution=10
)

esri_percentages
# Out:
# 2024-12-19 12:47:55,068 - environmental_risk_metrics.land_use_change - INFO - Loading ['io-lulc-annual-v02'] data at 10m resolution
# 2024-12-19 12:47:55,217 - environmental_risk_metrics.utils.planetary_computer - INFO - Searching for Sentinel-2 items between 2000-01-01 and 2024-12-31
# 2024-12-19 12:47:57,640 - environmental_risk_metrics.utils.planetary_computer - INFO - Found 7 items
# 100%|██████████| 7/7 [00:00<00:00, 16.30it/s]
# 2024-12-19 12:47:58,082 - environmental_risk_metrics.land_use_change - INFO - Loading ['io-lulc-annual-v02'] data at 10m resolution
# 2024-12-19 12:47:58,204 - environmental_risk_metrics.utils.planetary_computer - INFO - Searching for Sentinel-2 items between 2000-01-01 and 2024-12-31
# 2024-12-19 12:47:58,498 - environmental_risk_metrics.utils.planetary_computer - INFO - Found 7 items
# 100%|██████████| 7/7 [00:00<00:00, 114.97it/s]
# data        Crops
# time
# 2017-01-01  100.0
# 2018-01-01  100.0
# 2019-01-01  100.0
# 2020-01-01  100.0
# 2021-01-01  100.0
# 2022-01-01  100.0
# 2023-01-01  100.0

# %%
from environmental_risk_metrics import EsaLandCover, EsriLandCover, OpenLandMapLandCover

olanm_land_cover = OpenLandMapLandCover()

olanm = olanm_land_cover.load_xarray(
    start_date=start_date,
    end_date=end_date,
    polygon=polygon,
    resolution=10
)
# Out:
# 2024-12-19 14:51:21,828 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20000101_20001231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes
# 2024-12-19 14:51:22,340 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20050101_20051231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes
# 2024-12-19 14:51:22,622 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20100101_20101231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes
# 2024-12-19 14:51:22,964 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20150101_20151231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes
# 2024-12-19 14:51:23,314 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20200101_20201231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes

# %%
olanm_land_cover.get_land_use_class_percentages(
    start_date=start_date,
    end_date=end_date,
    polygon=polygon,
    polygon_crs="EPSG:4326",
    resolution=10
)
# Out:
# 2024-12-19 14:52:02,351 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20000101_20001231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes
# 2024-12-19 14:52:02,373 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20050101_20051231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes
# 2024-12-19 14:52:02,389 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20100101_20101231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes
# 2024-12-19 14:52:02,402 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20150101_20151231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes
# 2024-12-19 14:52:02,417 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20200101_20201231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes
# /Users/thimmzwiener/risk-reports/.venv/lib/python3.12/site-packages/xarray/core/duck_array_ops.py:226: RuntimeWarning: invalid value encountered in cast
#   return data.astype(dtype, **kwargs)
# class         NaN  \
# time
# 2000-01-01  28.95
# 2005-01-01  28.95
# 2010-01-01  28.95
# 2015-01-01  28.95
# 2020-01-01  28.95
#
# class       Terra Firma, dense short vegetation - 100% short veg. cover (24)  \
# time
# 2000-01-01                                               1.24
# 2005-01-01                                               0.46
# 2010-01-01                                               0.46
# 2015-01-01                                               0.46
# 2020-01-01                                               0.46
#
# class       Terra Firma, stable tree cover - 5m trees (27)  \
# time
# 2000-01-01                                            0.15
# 2005-01-01                                             NaN
# 2010-01-01                                             NaN
# 2015-01-01                                             NaN
# 2020-01-01                                             NaN
#
# class       Cropland, Stable (244)  Built-up, stable built-up (250)
# time
# 2000-01-01                   67.03                             2.63
# 2005-01-01                   58.36                            12.23
# 2010-01-01                   58.36                            12.23
# 2015-01-01                   58.36                            12.23
# 2020-01-01                   57.74                            12.85

# %%
luc = esa_land_cover.load_xarray(
    start_date=start_date,
    end_date=end_date,
    polygon=polygon,
    resolution=0.00009
)

class_percentages = esa_land_cover.get_land_use_class_percentages(
    start_date=start_date,
    end_date=end_date,
    polygon=polygon,
    polygon_crs="EPSG:4326",
    resolution=0.00009
)

class_percentages
# Out:
# 2024-12-19 13:04:53,907 - environmental_risk_metrics.land_use_change - INFO - Loading ['esa-cci-lc'] data at 9e-05m resolution
# 2024-12-19 13:04:54,011 - environmental_risk_metrics.utils.planetary_computer - INFO - Searching for Sentinel-2 items between 2000-01-01 and 2024-12-31
# 2024-12-19 13:04:54,502 - environmental_risk_metrics.utils.planetary_computer - INFO - Found 21 items
#   0%|          | 0/21 [00:00<?, ?it/s]/Users/thimmzwiener/risk-reports/.venv/lib/python3.12/site-packages/rasterio/warp.py:387: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dest = _reproject(
# 100%|██████████| 21/21 [00:00<00:00, 36.02it/s]
# 2024-12-19 13:04:55,113 - environmental_risk_metrics.land_use_change - INFO - Loading ['esa-cci-lc'] data at 9e-05m resolution
# 2024-12-19 13:04:55,223 - environmental_risk_metrics.utils.planetary_computer - INFO - Searching for Sentinel-2 items between 2000-01-01 and 2024-12-31
# 2024-12-19 13:04:55,587 - environmental_risk_metrics.utils.planetary_computer - INFO - Found 21 items
# 100%|██████████| 21/21 [00:00<00:00, 526.57it/s]
# lccs_class  Crops
# time
# 2000-01-01  100.0
# 2001-01-01  100.0
# 2002-01-01  100.0
# 2003-01-01  100.0
# 2004-01-01  100.0
# 2005-01-01  100.0
# 2006-01-01  100.0
# 2007-01-01  100.0
# 2008-01-01  100.0
# 2009-01-01  100.0
# 2010-01-01  100.0
# 2011-01-01  100.0
# 2012-01-01  100.0
# 2013-01-01  100.0
# 2014-01-01  100.0
# 2015-01-01  100.0
# 2016-01-01  100.0
# 2017-01-01  100.0
# 2018-01-01  100.0
# 2019-01-01  100.0
# 2020-01-01  100.0

# %%
import geopandas as gpd
polygon_df = gpd.GeoDataFrame.from_features([polygon])
minx, miny, maxx, maxy = polygon_df.bounds.iloc[
            0
        ]
minx, miny, maxx, maxy
# Out:
# (10.235198982658801, 51.41697045550828, 10.244461712820623, 51.4220355049745)

# %%
olanm_land_cover = OpenLandMapLandCover(use_esri_classes=True)

olanm_percentages = olanm_land_cover.get_land_use_class_percentages(
    start_date=start_date,
    end_date=end_date,
    polygon=polygon,
    polygon_crs="EPSG:4326",
    resolution=10
)
olanm_percentages
# Out:
# 2024-12-19 15:10:49,283 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20000101_20001231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes
# 2024-12-19 15:10:49,299 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20050101_20051231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes
# 2024-12-19 15:10:49,314 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20100101_20101231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes
# 2024-12-19 15:10:49,326 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20150101_20151231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes
# 2024-12-19 15:10:49,340 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20200101_20201231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes
# /Users/thimmzwiener/risk-reports/.venv/lib/python3.12/site-packages/xarray/core/duck_array_ops.py:226: RuntimeWarning: invalid value encountered in cast
#   return data.astype(dtype, **kwargs)
# class       Built area  Crops  Rangeland  Trees
# time
# 2000-01-01        3.70  94.34       1.74   0.22
# 2005-01-01       17.21  82.14       0.65   0.00
# 2010-01-01       17.21  82.14       0.65   0.00
# 2015-01-01       17.21  82.14       0.65   0.00
# 2020-01-01       18.08  81.26       0.65   0.00
